# %%
pip install spacy==2.3.0
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 40.0 MB/s
# ...
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ...

# %%
pip install wordcloud

# %%
import spacy

# %%
spacy.__version__
# Out:
# '2.2.4'

# %%
# !python -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.3.0) ======================
# ℹ spaCy installation: /usr/local/lib/python3.7/dist-packages/spacy
#
# TYPE      NAME             MODEL            VERSION
# package   en-core-web-sm   en_core_web_sm   2.2.5   --> 2.3.0
#
#
# ============================== Install updates ==============================
# Use the following commands to update the model packages:
# python -m spacy download en_core_web_sm

# %%
#pip install -U preshed

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 5.2 MB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.0-py3-none-any.whl size=12048605 sha256=8b8b2b43d34e5e3e34b7603adb51fbfdce5fc293f7e5298b31960fe85f0c6556
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pplycw4l/wheels/71/4a/56/e48f8ad9359a6780edd8cdd42955519b1a21d6365ad15628a2
# Successfully built en-core-web-sm
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      |████████████████████████████████| 50.8 MB 1.1 MB/s
# ...
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.3.0-py3-none-any.whl size=50921514 sha256=e55ad46ae52935be458f37f91c5cc4acced2e4ee582e54ceff3470874f83cef4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4f4j3pcz/wheels/a9/30/7d/40a0d13f1ddae5b6398c9f407391942152348eb9eae62fa21e
# Successfully built en-core-web-md
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings
import spacy # language models

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
# Problem statement 1: Perform sentimental analysis on the Elon-musk tweets (Exlon-musk.csv)

# %%
import pandas
Elon=pd.read_csv("Elon_musk.csv",error_bad_lines=False,encoding='cp1252')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Elon.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 I’m an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
Elon=Elon.iloc[::,1:2]
Elon
# Out:
#                                                    Text
# 0                                @kunalb11 I’m an alien
# 1     @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2                   @joerogan @Spotify Great interview!
# 3                       @gtera27 Doge is underestimated
# 4     @teslacn Congratulations Tesla China for amazi...
# ...                                                 ...
# 1994  @flcnhvy True, it sounds so surreal, but the n...
# 1995  @PPathole Make sure to read ur terms &amp; con...
# 1996                @TeslaGong @PPathole Samwise Gamgee
# 1997  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998                          Progress update August 28
#
# [1999 rows x 1 columns]

# %%
import re

# %%
Elon.Text=Elon.Text.apply(lambda x: re.sub('[^a-zA-Z ]', "", x))

# %%
Elon.Text=Elon.Text.apply(lambda x: x.lower())

# %%
Elon
# Out:
#                                                    Text
# 0                                    kunalb im an alien
# 1     idaacarmack ray tracing on cyberpunk with hdr ...
# 2                      joerogan spotify great interview
# 3                          gtera doge is underestimated
# 4     teslacn congratulations tesla china for amazin...
# ...                                                 ...
# 1994  flcnhvy true it sounds so surreal but the nega...
# 1995  ppathole make sure to read ur terms amp condit...
# 1996                  teslagong ppathole samwise gamgee
# 1997             ppathole altho dumb and dumber is ufuf
# 1998                            progress update august
#
# [1999 rows x 1 columns]

# %%
import nltk  
nltk.download('stopwords') 
from nltk.corpus import stopwords  
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
Elon.Text=Elon.Text.apply(lambda x: x.split())
Elon
# Out:
#                                                    Text
# 0                               [kunalb, im, an, alien]
# 1     [idaacarmack, ray, tracing, on, cyberpunk, wit...
# 2                 [joerogan, spotify, great, interview]
# 3                     [gtera, doge, is, underestimated]
# 4     [teslacn, congratulations, tesla, china, for, ...
# ...                                                 ...
# 1994  [flcnhvy, true, it, sounds, so, surreal, but, ...
# 1995  [ppathole, make, sure, to, read, ur, terms, am...
# 1996             [teslagong, ppathole, samwise, gamgee]
# 1997     [ppathole, altho, dumb, and, dumber, is, ufuf]
# 1998                         [progress, update, august]
#
# [1999 rows x 1 columns]

# %%
Elon.Text=Elon.Text.apply(lambda x: [word  for word in x if word not in set(stopwords.words('english'))])
Elon
# Out:
#                                                    Text
# 0                                   [kunalb, im, alien]
# 1     [idaacarmack, ray, tracing, cyberpunk, hdr, ne...
# 2                 [joerogan, spotify, great, interview]
# 3                         [gtera, doge, underestimated]
# 4     [teslacn, congratulations, tesla, china, amazi...
# ...                                                 ...
# 1994  [flcnhvy, true, sounds, surreal, negative, pro...
# 1995  [ppathole, make, sure, read, ur, terms, amp, c...
# 1996             [teslagong, ppathole, samwise, gamgee]
# 1997              [ppathole, altho, dumb, dumber, ufuf]
# 1998                         [progress, update, august]
#
# [1999 rows x 1 columns]

# %%
Elon.Text=Elon.Text.apply(lambda x: " ".join(x))

# %%
Elon
# Out:
#                                                    Text
# 0                                       kunalb im alien
# 1     idaacarmack ray tracing cyberpunk hdr nextleve...
# 2                      joerogan spotify great interview
# 3                             gtera doge underestimated
# 4     teslacn congratulations tesla china amazing ex...
# ...                                                 ...
# 1994  flcnhvy true sounds surreal negative propagand...
# 1995  ppathole make sure read ur terms amp condition...
# 1996                  teslagong ppathole samwise gamgee
# 1997                    ppathole altho dumb dumber ufuf
# 1998                             progress update august
#
# [1999 rows x 1 columns]

# %%
import re
import numpy as np
import pandas as pd

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(u"This is a sentence.")

# %%
one_block
# Out:
# 'sruhle everyone tesla receives stock comp stockoptions take table thats youre missing'

# %%
doc_block = nlp(one_block)
for token in doc_block[:]:
    print(token,"==>", token.pos_)
# Out:
# sruhle ==> PROPN
# everyone ==> PRON
# tesla ==> PROPN
# receives ==> VERB
# stock ==> NOUN
# comp ==> PROPN
# stockoptions ==> NOUN
# take ==> VERB
# table ==> NOUN
# that ==> DET
# s ==> VERB
# you ==> PRON
# re ==> VERB
# missing ==> VERB

# %%
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN', 'VERB')]
print(nouns_verbs[5:25])
# Out:
# ['s', 're', 'missing']

# %%
#Emotional mining

# %%
#Sentiment analysis
afinn = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
afinn.sample(20)
# Out:
#               word  value
# 55           admit     -1
# 1189     hindrance     -2
# 2121    stimulates      1
# 2157      stunning      4
# 390       cheering      2
# 2077      soothing      3
# 1581     murdering     -3
# 1072      generous      2
# 2047          slut     -5
# 730    disregarded     -2
# 615         denies     -2
# 2472         yucky     -2
# 2411          weak     -2
# 2070        solves      1
# 873         errors     -2
# 220         backed      1
# 692   discontented     -2
# 1509    melancholy     -2
# 538       crushing     -1
# 300         boosts      1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()

# %%
affinity_scores["great"]
# Out:
# 3

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
#nlp = spacy.load('en')
#sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += affinity_scores.get(word.lemma_, 0)
    return sent_score

# %%
# test that it works
calculate_sentiment(text = 'i am very happy')
# Out:
# 3

# %%
Elon['sentiment_value'] = Elon['Text'].apply(calculate_sentiment)

# %%
Elon
# Out:
#                                                    Text  sentiment_value
# 0                                       kunalb im alien                0
# 1     idaacarmack ray tracing cyberpunk hdr nextleve...                0
# 2                      joerogan spotify great interview                3
# 3                             gtera doge underestimated               -1
# 4     teslacn congratulations tesla china amazing ex...                6
# ...                                                 ...              ...
# 1994  flcnhvy true sounds surreal negative propagand...               -3
# 1995  ppathole make sure read ur terms amp condition...                1
# 1996                  teslagong ppathole samwise gamgee                0
# 1997                    ppathole altho dumb dumber ufuf               -6
# 1998                             progress update august                2
#
# [1999 rows x 2 columns]

# %%
calculate_sentiment(text ='Really liked this phone with awesome features such as 120hz super amoled display and 5000 MaH battery with 67W charging with a 108mp triple camera and a decent performance with snapdragon 695 with 7 5G bands support.As a user review I should recommend this for a everyday use phone and this phone is not a perfonmance centric phone but performance is decent')
# Out:
# 13

# %%
#Problem statement TWO:
#1) Extract reviews of any product from ecommerce website like amazon
#2) Perform emotion mining

# %%
reviews =pd.read_csv("reviews.csv",error_bad_lines=False)
reviews
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 id           profileName  \
# 0   R28KKK12P3M7ZH          Varun Bhagat
# 1   R32LN26ZA0ZSB9                 ashok
# 2   R35Q3BFLBS6O9S          Akash Sharma
# 3   R2WZPCPJ9HSTQT       Amazon Customer
# 4   R1GA0CITU0THUL            Saroj Heda
# 5   R2UAY6IVVBFB3H        Nagendra Reddy
# 6    R74EJ3K02HIRD                  D k.
# 7   R202AOGQIB1GGA     Lakshaya kothari
# 8   R2Y9U0TKWZLTUJ          Bikash kumar
# 9    RMU2M8R0KWK0F        Abhishek pujar
# 10  R1IAS1VOYNDOJ7               Sushank
# 11   RLOF57G27QYCE          Sahil Gautam
# 12   RTWR6WZAP637Z              S Sundar
# 13  R1SFGJ0ASYT3TK         Keerti Sharma
# 14  R1TDSXVG8EGDM3     rahul kumar singh
# 15  R1ERFOJJDGKKUC                Kedhar
# ...

# %%
reviews = reviews.iloc[::,2:3]
reviews.head(10)
# Out:
#                                                 text
# 0  \n  idk why the camera quality degraded so muc...
# 1                                 \n  overall good\n
# 2                                                NaN
# 3  \n  It is good, screen is great, it is fast an...
# 4  \n  I have exchange my redmi note 9 pro max ag...
# 5  \n  Got it for 10699 after exchange which is p...
# 6  \n   Phone is very good, it doesn't heat faste...
# 7  \n  Really liked this phone with awesome featu...
# 8                        \n  Too much awesome ....\n
# 9  \n  Very good phone and very bright screen and...

# %%
reviews.text.dropna(inplace=False)
# Out:
# 0     \n  idk why the camera quality degraded so muc...
# 1                                    \n  overall good\n
# 3     \n  It is good, screen is great, it is fast an...
# 4     \n  I have exchange my redmi note 9 pro max ag...
# 5     \n  Got it for 10699 after exchange which is p...
# 6     \n   Phone is very good, it doesn't heat faste...
# 7     \n  Really liked this phone with awesome featu...
# 8                           \n  Too much awesome ....\n
# 9     \n  Very good phone and very bright screen and...
# 10                        \n  Worst camera experience\n
# 11    \n  I'm describing this phone in some main poi...
# 12    \n   Waste mobile, Touch not working and hangi...
# 14    \n  I bought this phone for camera resolution ...
# 15    \n  I could Give 6 out of 5 for This Because B...
# 16    \n  Camera is very very bad, don't buy just lo...
# 17    \n  Overall a great phone... Loved every singl...
# 18    \n  Even the Amazon customer service also not ...
# ...

# %%
import re

# %%
reviews.text=reviews.text.dropna().apply(lambda x: re.sub('[^a-zA-Z ]', "", x))

# %%
reviews
# Out:
#                                                  text
# 0     idk why the camera quality degraded so much ...
# 1                                        overall good
# 2                                                 NaN
# 3     It is good screen is great it is fast and ch...
# 4     I have exchange my redmi note  pro max again...
# 5     Got it for  after exchange which is pretty g...
# 6     Phone is very good it doesnt heat faster tha...
# 7     Really liked this phone with awesome feature...
# 8                                   Too much awesome
# 9     Very good phone and very bright screen and a...
# 10                            Worst camera experience
# 11    Im describing this phone in some main points...
# 12    Waste mobile Touch not working and hanging d...
# 13                                                NaN
# 14    I bought this phone for camera resolution  m...
# 15    I could Give  out of  for This Because Best ...
# ...

# %%
reviews.text=reviews.text.dropna().apply(lambda x: x.lower())

# %%
reviews
# Out:
#                                                  text
# 0     idk why the camera quality degraded so much ...
# 1                                        overall good
# 2                                                 NaN
# 3     it is good screen is great it is fast and ch...
# 4     i have exchange my redmi note  pro max again...
# 5     got it for  after exchange which is pretty g...
# 6     phone is very good it doesnt heat faster tha...
# 7     really liked this phone with awesome feature...
# 8                                   too much awesome
# 9     very good phone and very bright screen and a...
# 10                            worst camera experience
# 11    im describing this phone in some main points...
# 12    waste mobile touch not working and hanging d...
# 13                                                NaN
# 14    i bought this phone for camera resolution  m...
# 15    i could give  out of  for this because best ...
# ...

# %%
import nltk  
nltk.download('stopwords') 
from nltk.corpus import stopwords  
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
reviews.text=reviews.text.dropna().apply(lambda x: x.split())
reviews
# Out:
#                                                  text
# 0   [idk, why, the, camera, quality, degraded, so,...
# 1                                     [overall, good]
# 2                                                 NaN
# 3   [it, is, good, screen, is, great, it, is, fast...
# 4   [i, have, exchange, my, redmi, note, pro, max,...
# 5   [got, it, for, after, exchange, which, is, pre...
# 6   [phone, is, very, good, it, doesnt, heat, fast...
# 7   [really, liked, this, phone, with, awesome, fe...
# 8                                [too, much, awesome]
# 9   [very, good, phone, and, very, bright, screen,...
# 10                        [worst, camera, experience]
# 11  [im, describing, this, phone, in, some, main, ...
# 12  [waste, mobile, touch, not, working, and, hang...
# 13                                                NaN
# 14  [i, bought, this, phone, for, camera, resoluti...
# 15  [i, could, give, out, of, for, this, because, ...
# ...

# %%
reviews.text=reviews.text.dropna().apply(lambda x: [word  for word in x if word not in set(stopwords.words('english'))])
reviews
# Out:
#                                                  text
# 0   [idk, camera, quality, degraded, much, rnpro, ...
# 1                                     [overall, good]
# 2                                                 NaN
# 3        [good, screen, great, fast, charging, quick]
# 4   [exchange, redmi, note, pro, max, phone, satis...
# 5     [got, exchange, pretty, goodgreat, job, xiaomi]
# 6   [phone, good, doesnt, heat, faster, phone, cam...
# 7   [really, liked, phone, awesome, features, hz, ...
# 8                                     [much, awesome]
# 9   [good, phone, bright, screen, asome, camera, c...
# 10                        [worst, camera, experience]
# 11  [im, describing, phone, main, points, fast, pr...
# 12  [waste, mobile, touch, working, hanging, dont,...
# 13                                                NaN
# 14  [bought, phone, camera, resolution, mpbut, cli...
# 15                  [could, give, best, phone, price]
# ...

# %%
reviews.text=reviews.text.dropna().apply(lambda x: " ".join(x))

# %%
reviews
# Out:
#                                                  text
# 0   idk camera quality degraded much rnpro camera ...
# 1                                        overall good
# 2                                                 NaN
# 3               good screen great fast charging quick
# 4   exchange redmi note pro max phone satisfied ph...
# 5            got exchange pretty goodgreat job xiaomi
# 6   phone good doesnt heat faster phone camera ai ...
# 7   really liked phone awesome features hz super a...
# 8                                        much awesome
# 9   good phone bright screen asome camera charging...
# 10                            worst camera experience
# 11  im describing phone main points fast processor...
# 12  waste mobile touch working hanging dont mi pro...
# 13                                                NaN
# 14  bought phone camera resolution mpbut click ima...
# 15                        could give best phone price
# ...

# %%
import re
import numpy as np
import pandas as pd

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(u"This is a sentence.")

# %%
#Sentiment analysis
afinn = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
afinn.sample(20)
# Out:
#                word  value
# 1486          lurks     -1
# 1890      respected      2
# 831   encouragement      2
# 57         admitted     -1
# 1586          naive     -2
# 2064          solid      2
# 183         asshole     -4
# 2205       swindles     -3
# 1345     interrupts     -2
# 603       delighted      3
# 1878        rescued      2
# 490      contending     -1
# 1423           leak     -1
# 1320  insignificant     -2
# 814         elation      3
# 1495   manipulation     -1
# 963         fatigue     -2
# 2349        useless     -2
# 1444      litigious     -2
# 1085          glory      2

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()

# %%
affinity_scores["great"]
# Out:
# 3

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
#nlp = spacy.load('en')
#sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += affinity_scores.get(word.lemma_, 0)
    return sent_score

# %%
# test that it works
calculate_sentiment(text = 'i am very happy')
# Out:
# 3

# %%
reviews['sentiment_value'] = reviews['text'].dropna().apply(calculate_sentiment)

# %%
reviews
# Out:
#                                                  text  sentiment_value
# 0   idk camera quality degraded much rnpro camera ...             -2.0
# 1                                        overall good              3.0
# 2                                                 NaN              NaN
# 3               good screen great fast charging quick              6.0
# 4   exchange redmi note pro max phone satisfied ph...              2.0
# 5            got exchange pretty goodgreat job xiaomi              1.0
# 6   phone good doesnt heat faster phone camera ai ...              7.0
# 7   really liked phone awesome features hz super a...             11.0
# 8                                        much awesome              4.0
# 9   good phone bright screen asome camera charging...              4.0
# 10                            worst camera experience             -3.0
# 11  im describing phone main points fast processor...             10.0
# ...
